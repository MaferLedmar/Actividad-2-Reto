# %%
#Importamos Librerias
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Cargamos archivo
df_Argentina= pd.read_csv('Buenos Aires.csv') 
df_Argentina.head()
# Out:
#                    id                                       name    host_id  \
# 0  639280827847650582          Lugar encantador en vicente lopez  461943087
# 1            33712571             Ambiente familiar....tranquilo  187744857
# 2            32934967      Habitacion para viajeros, estudiantes  247809450
# 3            42042076                        Hotel Vicente Lopez  183363682
# 4            33424822  Departamento de 2 ambientes frente al río   36564453
#
#    host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Roberto                  NaN         Nuñez -34.52618  -58.48117
# 1   Griselda                  NaN  Villa Lugano -34.68885  -58.50478
# 2  Sebastian                  NaN     Mataderos -34.68112  -58.51895
# 3   Bernardo                  NaN         Nuñez -34.52638  -58.47069
# 4     Sandra                  NaN         Nuñez -34.51730  -58.47505
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   2880               1                  0         NaN
# 1  Entire home/apt   1230               2                  0         NaN
# 2     Private room   3697              15                  0         NaN
# 3     Private room   5500               1                  6  2021-10-10
# 4  Entire home/apt   1915              15                  3  2021-07-24
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                NaN                               1               364
# 1                NaN                               1                89
# 2                NaN                               1               365
# 3               0.21                               2                73
# 4               0.21                              15               205
#
#    number_of_reviews_ltm license
# 0                      0     NaN
# 1                      0     NaN
# 2                      0     NaN
# 3                      1     NaN
# 4                      2     NaN

# %%
#Eliminamos columnas innecesarias para el análisis actual
data = df_Argentina.copy()
data.drop(['id', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude','name', 'license', 'room_type', 'last_review'],
 axis = 'columns', inplace=True)
data
# Out:
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0       2880               1                  0                NaN
# 1       1230               2                  0                NaN
# 2       3697              15                  0                NaN
# 3       5500               1                  6               0.21
# 4       1915              15                  3               0.21
# ...      ...             ...                ...                ...
# 16190  17252               3                 18               0.45
# 16191   9436               2                 16               0.18
# 16192   7394              14                  2               0.03
# 16193   6162               2                 23               4.21
# 16194   8450               1                 79               2.37
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                   1               364                      0
# 1                                   1                89                      0
# 2                                   1               365                      0
# 3                                   2                73                      1
# 4                                  15               205                      2
# ...                               ...               ...                    ...
# 16190                              15                60                      4
# 16191                               4               219                      0
# 16192                               2               365                      0
# 16193                              47               173                     23
# 16194                               1               232                     37
#
# [16195 rows x 7 columns]

# %%
#Detectamos valores nulos
valores_nulos = data.isnull().sum()
valores_nulos
# Out:
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 3527
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
#Copia del dataframe
data2=data.copy()
#Realizar valores nulos con promedio 
data2["reviews_per_month"]=data2["reviews_per_month"].fillna(round(data["reviews_per_month"].mean(),1))
data2
# Out:
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0       2880               1                  0               0.90
# 1       1230               2                  0               0.90
# 2       3697              15                  0               0.90
# 3       5500               1                  6               0.21
# 4       1915              15                  3               0.21
# ...      ...             ...                ...                ...
# 16190  17252               3                 18               0.45
# 16191   9436               2                 16               0.18
# 16192   7394              14                  2               0.03
# 16193   6162               2                 23               4.21
# 16194   8450               1                 79               2.37
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                   1               364                      0
# 1                                   1                89                      0
# 2                                   1               365                      0
# 3                                   2                73                      1
# 4                                  15               205                      2
# ...                               ...               ...                    ...
# 16190                              15                60                      4
# 16191                               4               219                      0
# 16192                               2               365                      0
# 16193                              47               173                     23
# 16194                               1               232                     37
#
# [16195 rows x 7 columns]

# %%
#Corroboramos que no existan valores nulos
#Detectamos valores nulos
valores_nulos = data2.isnull().sum()
valores_nulos
# Out:
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64
